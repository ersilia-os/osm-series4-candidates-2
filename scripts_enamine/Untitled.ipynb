# %%
import pandas as pd

# %%
df = pd.read_csv("../data/evariste/enamine_boronics_virtual_lib.csv")

# %%
df
# Out:
#     Unnamed: 0                                             smiles  potency_mu  \
# 0         1976    Fc1ccc(CCOc2cncc3nnc(-c4cnc5[nH]ccc5c4)n23)cc1F    6.410090
# 1         1600  Fc1ccc(CCOc2cncc3nnc(-c4ccc(Cl)c(C(F)(F)F)c4)n...    6.100415
# 2         1868   COc1cc(-c2nnc3cncc(OCCc4ccc(F)c(F)c4)n23)cc(C)n1    6.264949
# 3         1548      Fc1ccc(CCOc2cncc3nnc(-c4cccc5cccnc45)n23)cc1F    5.525821
# 4         1216  Fc1ccc(CCOc2cncc3nnc(-c4ccc5[nH]c(C(F)(F)F)cc5...    5.714834
# ..         ...                                                ...         ...
# 94        1994     Fc1ccc(CCOc2cncc3nnc(-c4ccc(C(F)F)nc4)n23)cc1F    5.982482
# 95          54  COC(=O)c1cc(-c2nnc3cncc(OCCc4ccc(F)c(F)c4)n23)...    5.667456
# 96        1851  N#Cc1ccc(-c2nnc3cncc(OCCc4ccc(F)c(F)c4)n23)c(F)c1    5.693086
# 97         156  Fc1ccc(CCOc2cncc3nnc(-c4cc(Cl)nc(C(F)(F)F)c4)n...    5.770474
# 98        2112  O=c1[nH]ncc2ccc(-c3nnc4cncc(OCCc5ccc(F)c(F)c5)...    5.833528
#
# ...

# %%
columns = list(df.columns)
df = df[columns[1:]]

# %%
df.to_csv("results/3_data.csv", index=False)
